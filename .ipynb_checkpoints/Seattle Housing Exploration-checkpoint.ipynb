# %%
import copy
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.style as style
import matplotlib.gridspec as gridspec
import seaborn as sns
from mpl_toolkits import mplot3d
from scipy import stats
# %matplotlib inline

# %%
df = pd.read_csv('./data_mod_1.csv')
df
# Out:
#          price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0     309620.0         3       2.50         1860      3730     2.0
# 1     625000.0         3       3.00         1820      1641     3.0
# 2     600000.0         2       1.00          910      2002     1.5
# 3     460000.0         2       2.25         1230       929     2.0
# 4     575000.0         3       1.75         2680      8625     1.0
# ...        ...       ...        ...          ...       ...     ...
# 4546  627000.0         3       3.50         2710      3475     2.0
# 4547  754800.0         2       2.50         2770      7781     2.0
# 4548  435000.0         3       2.50         1900      7984     2.0
# 4549  735000.0         5       2.75         3390      5211     2.0
# 4550  693000.0         3       2.50         2460     12028     2.0
#
#       waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0              0     0          3        1860              0      2012
# ...

# %%
df.columns
# Out:
# Index(['price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors',
#        'waterfront', 'view', 'condition', 'sqft_above', 'sqft_basement',
#        'yr_built', 'yr_renovated', 'street', 'city', 'statezip', 'country',
#        'Unnamed: 17'],
#       dtype='object')

# %%
# features = ['price', 'bedrooms', 'bathrooms', 'sqft_living', 'floors', 'waterfront', 'view', 'condition', 'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'street', 'city', 'statezip', 'country']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4551 entries, 0 to 4550
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   price          4551 non-null   float64
#  1   bedrooms       4551 non-null   int64
#  2   bathrooms      4551 non-null   float64
#  3   sqft_living    4551 non-null   int64
#  4   sqft_lot       4551 non-null   int64
#  5   floors         4551 non-null   float64
#  6   waterfront     4551 non-null   int64
#  7   view           4551 non-null   int64
#  8   condition      4551 non-null   int64
#  9   sqft_above     4551 non-null   int64
#  10  sqft_basement  4551 non-null   int64
#  11  yr_built       4551 non-null   int64
#  12  yr_renovated   4551 non-null   int64
#  13  street         4551 non-null   object
#  14  city           4551 non-null   object
#  15  statezip       4551 non-null   object
#  16  country        4551 non-null   object
# ...

# %%
df.isnull().sum()  # no missing valuesc
# Out:
# price               0
# bedrooms            0
# bathrooms           0
# sqft_living         0
# sqft_lot            0
# floors              0
# waterfront          0
# view                0
# condition           0
# sqft_above          0
# sqft_basement       0
# yr_built            0
# yr_renovated        0
# street              0
# city                0
# statezip            0
# country             0
# Unnamed: 17      4550
# dtype: int64

# %%
df['price']
# Out:
# 0       309620.0
# 1       625000.0
# 2       600000.0
# 3       460000.0
# 4       575000.0
#           ...
# 4546    627000.0
# 4547    754800.0
# 4548    435000.0
# 4549    735000.0
# 4550    693000.0
# Name: price, Length: 4551, dtype: float64

# %%
df[0:3]  # what does a sample of three look like
# Out:
#       price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  309620.0         3        2.5         1860      3730     2.0           0
# 1  625000.0         3        3.0         1820      1641     3.0           0
# 2  600000.0         2        1.0          910      2002     1.5           0
#
#    view  condition  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3        1860              0      2012          1912
# 1     0          3        1540            280      2006             0
# 2     0          3         910              0      1900          2005
#
#             street     city  statezip country Unnamed: 17
# 0     1 View Ln NE   Duvall  WA 98019     USA         NaN
# 1  10 W Etruria St  Seattle  WA 98119     USA         NaN
# 2   100 20th Ave E  Seattle  WA 98112     USA         NaN

# %% [markdown]
# ### Data Exploration

# %% [markdown]
# The following is a bit of pre-exploration.
#
# We've constructed 3 subset dataframes of the main dataframe (df_0, df_1, df_2)

# %%
df_0 = df.iloc[:, 0:4]  # first 4 columns
df_0
# Out:
#          price  bedrooms  bathrooms  sqft_living
# 0     309620.0         3       2.50         1860
# 1     625000.0         3       3.00         1820
# 2     600000.0         2       1.00          910
# 3     460000.0         2       2.25         1230
# 4     575000.0         3       1.75         2680
# ...        ...       ...        ...          ...
# 4546  627000.0         3       3.50         2710
# 4547  754800.0         2       2.50         2770
# 4548  435000.0         3       2.50         1900
# 4549  735000.0         5       2.75         3390
# 4550  693000.0         3       2.50         2460
#
# [4551 rows x 4 columns]

# %%
df_0.describe()
# Out:
#               price     bedrooms    bathrooms   sqft_living
# count  4.551000e+03  4551.000000  4551.000000   4551.000000
# mean   5.579059e+05     3.394639     2.155021   2132.372226
# std    5.639299e+05     0.904595     0.776351    955.949708
# min    7.800000e+03     0.000000     0.000000    370.000000
# 25%    3.262643e+05     3.000000     1.750000   1460.000000
# 50%    4.650000e+05     3.000000     2.250000   1970.000000
# 75%    6.575000e+05     4.000000     2.500000   2610.000000
# max    2.659000e+07     9.000000     8.000000  13540.000000

# %%
df_1 = df.loc[:, ('city', 'statezip', 'price')]  # another way of accessing the columns
df_1
# Out:
#            city  statezip     price
# 0        Duvall  WA 98019  309620.0
# 1       Seattle  WA 98119  625000.0
# 2       Seattle  WA 98112  600000.0
# 3       Seattle  WA 98112  460000.0
# 4      Issaquah  WA 98027  575000.0
# ...         ...       ...       ...
# 4546   Issaquah  WA 98027  627000.0
# 4547    Redmond  WA 98053  754800.0
# 4548    Bothell  WA 98011  435000.0
# 4549  Sammamish  WA 98075  735000.0
# 4550    Redmond  WA 98052  693000.0
#
# [4551 rows x 3 columns]

# %%
df_1_sample = df_1.sample(frac=0.01, random_state=1)  # working with a subset of df_1

# %%
df_1_sample.describe().round(1)
# Out:
#            price
# count       46.0
# mean    547069.5
# std     218260.3
# min     185000.0
# 25%     421250.0
# 50%     520750.0
# 75%     661250.0
# max    1270000.0

# %%
df_1.describe().round(1)  # the mean for the sample and population are similar
# Out:
#             price
# count      4551.0
# mean     557905.9
# std      563929.9
# min        7800.0
# 25%      326264.3
# 50%      465000.0
# 75%      657500.0
# max    26590000.0

# %% [markdown]
# ### Grouping by City

# %%
grouped_by_city = df_1.groupby(['city'])
grouped_by_city.describe().round(1)
# Out:
#                       price                                             \
#                       count       mean        std       min        25%
# city
# Algona                  5.0   207288.0    64798.0  100000.0   196440.0
# Auburn                175.0   301051.0   128904.0   87500.0   224250.0
# Beaux Arts Village      1.0   745000.0        NaN  745000.0   745000.0
# Bellevue              281.0   862255.1   587972.6  248000.0   540000.0
# Black Diamond           8.0   382056.2   164825.4  224000.0   248487.5
# Bothell                33.0   481441.9    98892.0  347000.0   420000.0
# Burien                 72.0   358640.2   209654.5  100000.0   214000.0
# Carnation              22.0   508752.0   332710.9   80000.0   301000.0
# Clyde Hill              9.0  1615711.1   927005.6  927000.0  1110000.0
# Covington              42.0   303283.5   309935.9   83300.0   220112.5
# Des Moines             58.0   304992.5   156312.0  140000.0   210000.0
# ...

# %% [markdown]
# Seattle city has an average home price of approximately $584,000. Medina, Mercer Island, Yarrow Point are affluent neighbourhoods. Algona has the least expensive homes.

# %%
df_2 = df.loc[:, ('city', 'bedrooms', 'price')]
df_2
# Out:
#            city  bedrooms     price
# 0        Duvall         3  309620.0
# 1       Seattle         3  625000.0
# 2       Seattle         2  600000.0
# 3       Seattle         2  460000.0
# 4      Issaquah         3  575000.0
# ...         ...       ...       ...
# 4546   Issaquah         3  627000.0
# 4547    Redmond         2  754800.0
# 4548    Bothell         3  435000.0
# 4549  Sammamish         5  735000.0
# 4550    Redmond         3  693000.0
#
# [4551 rows x 3 columns]

# %%
grouped_by_city_and_bedroom = df_2.groupby(['city', 'bedrooms'])
grouped_by_city_and_bedroom.describe().round(1)
# Out:
#                       price                                             \
#                       count       mean       std        min        25%
# city         bedrooms
# Algona       2          1.0   100000.0       NaN   100000.0   100000.0
#              3          2.0   213220.0   23730.5   196440.0   204830.0
#              4          2.0   255000.0    9899.5   248000.0   251500.0
# Auburn       1          1.0   115000.0       NaN   115000.0   115000.0
#              2         13.0   245892.3  106306.2    87500.0   189000.0
# ...                     ...        ...       ...        ...        ...
# Woodinville  5          6.0   711000.0  210236.3   480000.0   517125.0
#              6          1.0  1135000.0       NaN  1135000.0  1135000.0
# Yarrow Point 3          2.0  1400000.0  708521.0   899000.0  1149500.0
#              4          1.0    84350.0       NaN    84350.0    84350.0
#              5          1.0  1895000.0       NaN  1895000.0  1895000.0
#
#
# ...

# %%
df_3 = df.loc[:, ('city', 'condition', 'price')]
df_3
# Out:
#            city  condition     price
# 0        Duvall          3  309620.0
# 1       Seattle          3  625000.0
# 2       Seattle          3  600000.0
# 3       Seattle          3  460000.0
# 4      Issaquah          5  575000.0
# ...         ...        ...       ...
# 4546   Issaquah          3  627000.0
# 4547    Redmond          3  754800.0
# 4548    Bothell          3  435000.0
# 4549  Sammamish          3  735000.0
# 4550    Redmond          3  693000.0
#
# [4551 rows x 3 columns]

# %%
grouped_by_city_and_condition = df_3.groupby(['city', 'condition'])
grouped_by_city_and_condition.describe().round(1)
# Out:
#                         price                                             \
#                         count       mean       std        min        25%
# city         condition
# Algona       3            4.0   201610.0   73371.9   100000.0   172330.0
#              4            1.0   230000.0       NaN   230000.0   230000.0
# Auburn       2            2.0   325000.0   14142.1   315000.0   320000.0
#              3          111.0   326396.5  138264.1   132500.0   250000.0
#              4           52.0   256873.2  103494.8    87500.0   199125.0
# ...                       ...        ...       ...        ...        ...
# Woodinville  3           74.0   629496.8  254199.5   278900.0   459500.0
#              4           35.0   589520.4  219519.7   306000.0   421062.5
#              5            4.0   658500.0  345686.3   360000.0   438750.0
# Yarrow Point 3            1.0  1901000.0       NaN  1901000.0  1901000.0
# ...

# %% [markdown]
# ### Grouping by State ZIP Code

# %%
grouped_by_state = df_1.groupby(['statezip'])
grouped_by_state.describe().round(1)
# Out:
#           price                                                        \
#           count       mean        std       min        25%        50%
# statezip
# WA 98001   66.0   261639.9    91372.1  100000.0   201175.0   246500.0
# WA 98002   35.0   229934.4    46337.3   87500.0   205500.0   229500.0
# WA 98003   48.0   299425.6   133918.7  156000.0   220737.5   256250.0
# WA 98004   71.0  1372758.4   968619.9   84350.0   885000.0  1100000.0
# WA 98005   29.0   778779.2   275796.3  497333.3   625000.0   729032.0
# WA 98006  109.0   800328.3   328971.3  248000.0   550000.0   746000.0
# WA 98007   38.0   655921.9   222596.2  330000.0   509250.0   590000.0
# WA 98008   48.0   628086.6   381730.0  300000.0   454500.0   526500.0
# WA 98010    8.0   382056.2   164825.4  224000.0   248487.5   326500.0
# WA 98011   32.0   483518.2    99740.8  347000.0   423750.0   458000.0
# WA 98014   22.0   508752.0   332710.9   80000.0   301000.0   432175.0
# ...

# %% [markdown]
# I've noticed WA 98103 has a lot of counts with 148 samples. We can further explore this below.

# %% [markdown]
# # Exploring State Zip WA 98103
# We're honing into WA 98103 because it is a comfortable amount of samples to work with. Its small enough so that we can verify our machine learning algorithm results with our own hand calculations.

# %%
df  # recall what the original df looks like
# Out:
#          price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0     309620.0         3       2.50         1860      3730     2.0
# 1     625000.0         3       3.00         1820      1641     3.0
# 2     600000.0         2       1.00          910      2002     1.5
# 3     460000.0         2       2.25         1230       929     2.0
# 4     575000.0         3       1.75         2680      8625     1.0
# ...        ...       ...        ...          ...       ...     ...
# 4546  627000.0         3       3.50         2710      3475     2.0
# 4547  754800.0         2       2.50         2770      7781     2.0
# 4548  435000.0         3       2.50         1900      7984     2.0
# 4549  735000.0         5       2.75         3390      5211     2.0
# 4550  693000.0         3       2.50         2460     12028     2.0
#
#       waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0              0     0          3        1860              0      2012
# ...

# %% [markdown]
# ### State ZIP WA 98103 on the map

# %% [markdown]
# <img src="./98103.png">

# %%
df_4 = df.loc[ (df['statezip'] == 'WA 98103'), ['bedrooms', 'bathrooms', 'sqft_living', 'floors', 'condition', 'price'] ]
df_4.round(1)
# Out:
#       bedrooms  bathrooms  sqft_living  floors  condition     price
# 54           4        2.0         1790     1.0          4  475000.0
# 237          4        1.0         1210     1.5          3  452000.0
# 338          3        2.5         1770     3.0          3  436110.0
# 375          4        2.8         2610     3.0          5  650000.0
# 460          4        1.0         1600     1.5          4  485000.0
# ...        ...        ...          ...     ...        ...       ...
# 4468         3        3.2         1410     3.0          3  382000.0
# 4473         2        1.0         1260     1.0          4  405000.0
# 4475         2        1.0         1170     1.0          4  455000.0
# 4476         2        2.5         1260     3.0          3  350000.0
# 4502         2        1.0         1470     1.0          3  458663.9
#
# [148 rows x 6 columns]

# %% [markdown]
# Intuitively, we chose these features because we think these are the most significant. In other words, we think these features are what will determine the price

# %%
X_ = df_4.sqft_living  # intuitively, sqft is the most telling of price
X_
# Out:
# 54      1790
# 237     1210
# 338     1770
# 375     2610
# 460     1600
#         ...
# 4468    1410
# 4473    1260
# 4475    1170
# 4476    1260
# 4502    1470
# Name: sqft_living, Length: 148, dtype: int64

# %%
type(X_)  # we don't want a series..
# Out:
# pandas.core.series.Series

# %%
X = X_.to_numpy()  # we want a numpy array
X
# Out:
# array([1790, 1210, 1770, 2610, 1600,  800, 1030, 2000, 1270, 1440, 2280,
#        2020, 1170, 2650, 1680, 1420, 2360, 2880, 1800, 3730, 1060, 3460,
#        1430, 2000, 1240, 1200, 1760, 1950, 1250, 1150, 1400, 1630, 1260,
#        1400, 1420, 1420, 1780, 1550, 1210, 2030, 1660, 1410, 3330,  970,
#         950, 1270, 2180, 1990, 1680, 1540, 1960, 1390, 1980, 1890, 2080,
#        2350, 1500, 1380, 1290, 2870,  820, 1690, 1380, 1380, 2060, 2320,
#        1250,  820, 1080, 1420, 1550, 2140, 1780, 1620, 2980, 2630, 2100,
#        2230, 2750, 1710, 1830, 1370, 1740, 1440, 2520, 4360, 1360, 1210,
#        3440, 1800, 1730, 1420, 1430, 1890, 1290, 1020, 2340, 1800, 1910,
#        1910, 1240, 1650, 1590, 1570, 1810, 2200, 1430, 3010, 1460, 1620,
#         920, 3110, 1990, 2310,  830, 1060, 2140, 1520, 1980, 1310,  950,
#        1280, 1410, 1390, 3830, 1270, 1270, 1410, 1370, 1140, 1540, 1175,
#        2500, 2610, 1340, 1220, 1680,  700, 1370, 1530, 1070, 1150, 1410,
# ...

# %%
type(X)
# Out:
# numpy.ndarray

# %%
X
# Out:
# array([1790, 1210, 1770, 2610, 1600,  800, 1030, 2000, 1270, 1440, 2280,
#        2020, 1170, 2650, 1680, 1420, 2360, 2880, 1800, 3730, 1060, 3460,
#        1430, 2000, 1240, 1200, 1760, 1950, 1250, 1150, 1400, 1630, 1260,
#        1400, 1420, 1420, 1780, 1550, 1210, 2030, 1660, 1410, 3330,  970,
#         950, 1270, 2180, 1990, 1680, 1540, 1960, 1390, 1980, 1890, 2080,
#        2350, 1500, 1380, 1290, 2870,  820, 1690, 1380, 1380, 2060, 2320,
#        1250,  820, 1080, 1420, 1550, 2140, 1780, 1620, 2980, 2630, 2100,
#        2230, 2750, 1710, 1830, 1370, 1740, 1440, 2520, 4360, 1360, 1210,
#        3440, 1800, 1730, 1420, 1430, 1890, 1290, 1020, 2340, 1800, 1910,
#        1910, 1240, 1650, 1590, 1570, 1810, 2200, 1430, 3010, 1460, 1620,
#         920, 3110, 1990, 2310,  830, 1060, 2140, 1520, 1980, 1310,  950,
#        1280, 1410, 1390, 3830, 1270, 1270, 1410, 1370, 1140, 1540, 1175,
#        2500, 2610, 1340, 1220, 1680,  700, 1370, 1530, 1070, 1150, 1410,
# ...

# %%
X.shape
# Out:
# (148,)

# %% [markdown]
# ##### Data Preperation for Linear Regression

# %%
ones = np.ones(len(X))  # add a ones column in front

# %%
X_with_ones_col = np.column_stack((ones, X))
X_with_ones_col
# Out:
# array([[1.000e+00, 1.790e+03],
#        [1.000e+00, 1.210e+03],
#        [1.000e+00, 1.770e+03],
#        [1.000e+00, 2.610e+03],
#        [1.000e+00, 1.600e+03],
#        [1.000e+00, 8.000e+02],
#        [1.000e+00, 1.030e+03],
#        [1.000e+00, 2.000e+03],
#        [1.000e+00, 1.270e+03],
#        [1.000e+00, 1.440e+03],
#        [1.000e+00, 2.280e+03],
#        [1.000e+00, 2.020e+03],
#        [1.000e+00, 1.170e+03],
#        [1.000e+00, 2.650e+03],
#        [1.000e+00, 1.680e+03],
#        [1.000e+00, 1.420e+03],
#        [1.000e+00, 2.360e+03],
#        [1.000e+00, 2.880e+03],
#        [1.000e+00, 1.800e+03],
#        [1.000e+00, 3.730e+03],
#        [1.000e+00, 1.060e+03],
#        [1.000e+00, 3.460e+03],
#        [1.000e+00, 1.430e+03],
#        [1.000e+00, 2.000e+03],
#        [1.000e+00, 1.240e+03],
#        [1.000e+00, 1.200e+03],
#        [1.000e+00, 1.760e+03],
#        [1.000e+00, 1.950e+03],
#        [1.000e+00, 1.250e+03],
#        [1.000e+00, 1.150e+03],
# ...

# %%
X_with_ones_col = np.column_stack((ones, X))
X_with_ones_col
# Out:
# array([[1.000e+00, 1.790e+03],
#        [1.000e+00, 1.210e+03],
#        [1.000e+00, 1.770e+03],
#        [1.000e+00, 2.610e+03],
#        [1.000e+00, 1.600e+03],
#        [1.000e+00, 8.000e+02],
#        [1.000e+00, 1.030e+03],
#        [1.000e+00, 2.000e+03],
#        [1.000e+00, 1.270e+03],
#        [1.000e+00, 1.440e+03],
#        [1.000e+00, 2.280e+03],
#        [1.000e+00, 2.020e+03],
#        [1.000e+00, 1.170e+03],
#        [1.000e+00, 2.650e+03],
#        [1.000e+00, 1.680e+03],
#        [1.000e+00, 1.420e+03],
#        [1.000e+00, 2.360e+03],
#        [1.000e+00, 2.880e+03],
#        [1.000e+00, 1.800e+03],
#        [1.000e+00, 3.730e+03],
#        [1.000e+00, 1.060e+03],
#        [1.000e+00, 3.460e+03],
#        [1.000e+00, 1.430e+03],
#        [1.000e+00, 2.000e+03],
#        [1.000e+00, 1.240e+03],
#        [1.000e+00, 1.200e+03],
#        [1.000e+00, 1.760e+03],
#        [1.000e+00, 1.950e+03],
#        [1.000e+00, 1.250e+03],
#        [1.000e+00, 1.150e+03],
# ...

# %%
X_with_ones_col.shape
# Out:
# (148, 2)

# %% [markdown]
# ##### our target: y

# %%
y = df_4.price
y = y.to_numpy()
y.shape
# Out:
# (148,)

# %%
y
# Out:
# array([ 475000.    ,  452000.    ,  436110.    ,  650000.    ,
#         485000.    ,  370000.    ,  535000.    ,  677000.    ,
#         531000.    ,  445000.    ,  875000.    ,  720000.    ,
#         499000.    , 1008000.    ,  700000.    ,  371000.    ,
#         702500.    , 1125000.    ,  875000.    ,  595000.    ,
#         480000.    , 1315000.    ,  485000.    ,  585000.    ,
#         543000.    ,  504200.    ,  640000.    ,  725000.    ,
#         712000.    ,  425000.    ,  563500.    ,  609000.    ,
#         485000.    ,  474800.    ,  523950.    ,  510000.    ,
#         586500.    ,  526000.    ,  500000.    ,  831000.    ,
#         550607.1429,  500000.    ,  850000.    ,  690000.    ,
#         500000.    ,  355000.    ,  785000.    ,  760500.    ,
#         330000.    ,  690000.    ,  599000.    ,  657100.    ,
#         660000.    ,  486895.    ,  715000.    ,  870300.    ,
#         480000.    ,  482000.    ,  440000.    ,  765000.    ,
# ...

# %%
y.shape
# Out:
# (148,)

# %% [markdown]
# ### Plotting

# %%
X
# Out:
# array([1790, 1210, 1770, 2610, 1600,  800, 1030, 2000, 1270, 1440, 2280,
#        2020, 1170, 2650, 1680, 1420, 2360, 2880, 1800, 3730, 1060, 3460,
#        1430, 2000, 1240, 1200, 1760, 1950, 1250, 1150, 1400, 1630, 1260,
#        1400, 1420, 1420, 1780, 1550, 1210, 2030, 1660, 1410, 3330,  970,
#         950, 1270, 2180, 1990, 1680, 1540, 1960, 1390, 1980, 1890, 2080,
#        2350, 1500, 1380, 1290, 2870,  820, 1690, 1380, 1380, 2060, 2320,
#        1250,  820, 1080, 1420, 1550, 2140, 1780, 1620, 2980, 2630, 2100,
#        2230, 2750, 1710, 1830, 1370, 1740, 1440, 2520, 4360, 1360, 1210,
#        3440, 1800, 1730, 1420, 1430, 1890, 1290, 1020, 2340, 1800, 1910,
#        1910, 1240, 1650, 1590, 1570, 1810, 2200, 1430, 3010, 1460, 1620,
#         920, 3110, 1990, 2310,  830, 1060, 2140, 1520, 1980, 1310,  950,
#        1280, 1410, 1390, 3830, 1270, 1270, 1410, 1370, 1140, 1540, 1175,
#        2500, 2610, 1340, 1220, 1680,  700, 1370, 1530, 1070, 1150, 1410,
# ...

# %%
len(X)
# Out:
# 148

# %%
X_with_ones_col
# Out:
# array([[1.000e+00, 1.790e+03],
#        [1.000e+00, 1.210e+03],
#        [1.000e+00, 1.770e+03],
#        [1.000e+00, 2.610e+03],
#        [1.000e+00, 1.600e+03],
#        [1.000e+00, 8.000e+02],
#        [1.000e+00, 1.030e+03],
#        [1.000e+00, 2.000e+03],
#        [1.000e+00, 1.270e+03],
#        [1.000e+00, 1.440e+03],
#        [1.000e+00, 2.280e+03],
#        [1.000e+00, 2.020e+03],
#        [1.000e+00, 1.170e+03],
#        [1.000e+00, 2.650e+03],
#        [1.000e+00, 1.680e+03],
#        [1.000e+00, 1.420e+03],
#        [1.000e+00, 2.360e+03],
#        [1.000e+00, 2.880e+03],
#        [1.000e+00, 1.800e+03],
#        [1.000e+00, 3.730e+03],
#        [1.000e+00, 1.060e+03],
#        [1.000e+00, 3.460e+03],
#        [1.000e+00, 1.430e+03],
#        [1.000e+00, 2.000e+03],
#        [1.000e+00, 1.240e+03],
#        [1.000e+00, 1.200e+03],
#        [1.000e+00, 1.760e+03],
#        [1.000e+00, 1.950e+03],
#        [1.000e+00, 1.250e+03],
#        [1.000e+00, 1.150e+03],
# ...

# %%
X_with_ones_col.shape
# Out:
# (148, 2)

# %%
y
# Out:
# array([ 475000.    ,  452000.    ,  436110.    ,  650000.    ,
#         485000.    ,  370000.    ,  535000.    ,  677000.    ,
#         531000.    ,  445000.    ,  875000.    ,  720000.    ,
#         499000.    , 1008000.    ,  700000.    ,  371000.    ,
#         702500.    , 1125000.    ,  875000.    ,  595000.    ,
#         480000.    , 1315000.    ,  485000.    ,  585000.    ,
#         543000.    ,  504200.    ,  640000.    ,  725000.    ,
#         712000.    ,  425000.    ,  563500.    ,  609000.    ,
#         485000.    ,  474800.    ,  523950.    ,  510000.    ,
#         586500.    ,  526000.    ,  500000.    ,  831000.    ,
#         550607.1429,  500000.    ,  850000.    ,  690000.    ,
#         500000.    ,  355000.    ,  785000.    ,  760500.    ,
#         330000.    ,  690000.    ,  599000.    ,  657100.    ,
#         660000.    ,  486895.    ,  715000.    ,  870300.    ,
#         480000.    ,  482000.    ,  440000.    ,  765000.    ,
# ...

# %%
len(y)
# Out:
# 148

# %%
fig4, ax4 = plt.subplots()

ax4.scatter(X, y, s=10)  # this plot makes sense
ax4.axhline(0, color='black')
ax4.axvline(0, color='black')
ax4.set_title("Figure 1: Cost of Homes in Seattle (WA 98103)")
ax4.set_xlabel("House Size (sqft)")
ax4.set_ylabel("Cost ($)")
# Out:
# <img src="data:image/png;base64,..." width="432">
# Text(0, 0.5, 'Cost ($)')

# %%
# we can roughly see a trend, that as the sqft increases, so does the cost

# %% [markdown]
# ## SOLVING FOR WEIGHTS WITH LINEAR ALGEBRA

# %% [markdown]
# there's only one feature, we are definitely using linear algebra to solve for our weights in this example, aka our slope and intercept. even if there were 10,000 features, we should use linear algebra to solve.

# %%
def normal_equation(X, y):
    return np.linalg.inv(X.T @ X) @ X.T @ y

# %%
normal_equation(X_with_ones_col, y)
# Out:
# array([184435.24482113,    229.49521863])

# %%
# this looks reasonable, lets run a test. if we have 2000 sqft. then ...

# %%
184435.2448 + 229.4952 * 2000
# Out:
# 643425.6448

# %%
# looking with our graph above, that answer looks reasonable

# %% [markdown]
# ## SOLVING END

# %% [markdown]
# ### Scaling

# %% [markdown]
# for plotting purposes, it would be ideal to have weights close in value so we can plot a cost function. I'm going to scale the X by 1000 and the scale the y by 100,000

# %%
X_scaled = X/1000
X_scaled
# Out:
# array([1.79 , 1.21 , 1.77 , 2.61 , 1.6  , 0.8  , 1.03 , 2.   , 1.27 ,
#        1.44 , 2.28 , 2.02 , 1.17 , 2.65 , 1.68 , 1.42 , 2.36 , 2.88 ,
#        1.8  , 3.73 , 1.06 , 3.46 , 1.43 , 2.   , 1.24 , 1.2  , 1.76 ,
#        1.95 , 1.25 , 1.15 , 1.4  , 1.63 , 1.26 , 1.4  , 1.42 , 1.42 ,
#        1.78 , 1.55 , 1.21 , 2.03 , 1.66 , 1.41 , 3.33 , 0.97 , 0.95 ,
#        1.27 , 2.18 , 1.99 , 1.68 , 1.54 , 1.96 , 1.39 , 1.98 , 1.89 ,
#        2.08 , 2.35 , 1.5  , 1.38 , 1.29 , 2.87 , 0.82 , 1.69 , 1.38 ,
#        1.38 , 2.06 , 2.32 , 1.25 , 0.82 , 1.08 , 1.42 , 1.55 , 2.14 ,
#        1.78 , 1.62 , 2.98 , 2.63 , 2.1  , 2.23 , 2.75 , 1.71 , 1.83 ,
#        1.37 , 1.74 , 1.44 , 2.52 , 4.36 , 1.36 , 1.21 , 3.44 , 1.8  ,
#        1.73 , 1.42 , 1.43 , 1.89 , 1.29 , 1.02 , 2.34 , 1.8  , 1.91 ,
#        1.91 , 1.24 , 1.65 , 1.59 , 1.57 , 1.81 , 2.2  , 1.43 , 3.01 ,
#        1.46 , 1.62 , 0.92 , 3.11 , 1.99 , 2.31 , 0.83 , 1.06 , 2.14 ,
# ...

# %%
X_scaled_with_ones_col = np.column_stack((np.ones(len(X_scaled)), X_scaled))
X_scaled_with_ones_col
# Out:
# array([[1.   , 1.79 ],
#        [1.   , 1.21 ],
#        [1.   , 1.77 ],
#        [1.   , 2.61 ],
#        [1.   , 1.6  ],
#        [1.   , 0.8  ],
#        [1.   , 1.03 ],
#        [1.   , 2.   ],
#        [1.   , 1.27 ],
#        [1.   , 1.44 ],
#        [1.   , 2.28 ],
#        [1.   , 2.02 ],
#        [1.   , 1.17 ],
#        [1.   , 2.65 ],
#        [1.   , 1.68 ],
#        [1.   , 1.42 ],
#        [1.   , 2.36 ],
#        [1.   , 2.88 ],
#        [1.   , 1.8  ],
#        [1.   , 3.73 ],
#        [1.   , 1.06 ],
#        [1.   , 3.46 ],
#        [1.   , 1.43 ],
#        [1.   , 2.   ],
#        [1.   , 1.24 ],
#        [1.   , 1.2  ],
#        [1.   , 1.76 ],
#        [1.   , 1.95 ],
#        [1.   , 1.25 ],
#        [1.   , 1.15 ],
#        [1.   , 1.4  ],
#        [1.   , 1.63 ],
#        [1.   , 1.26 ],
#        [1.   , 1.4  ],
#        [1.   , 1.42 ],
#        [1.   , 1.42 ],
#        [1.   , 1.78 ],
#        [1.   , 1.55 ],
#        [1.   , 1.21 ],
#        [1.   , 2.03 ],
# ...

# %%
X_scaled_with_ones_col.shape
# Out:
# (148, 2)

# %%
y_scaled = y/100000
y_scaled
# Out:
# array([ 4.75      ,  4.52      ,  4.3611    ,  6.5       ,  4.85      ,
#         3.7       ,  5.35      ,  6.77      ,  5.31      ,  4.45      ,
#         8.75      ,  7.2       ,  4.99      , 10.08      ,  7.        ,
#         3.71      ,  7.025     , 11.25      ,  8.75      ,  5.95      ,
#         4.8       , 13.15      ,  4.85      ,  5.85      ,  5.43      ,
#         5.042     ,  6.4       ,  7.25      ,  7.12      ,  4.25      ,
#         5.635     ,  6.09      ,  4.85      ,  4.748     ,  5.2395    ,
#         5.1       ,  5.865     ,  5.26      ,  5.        ,  8.31      ,
#         5.50607143,  5.        ,  8.5       ,  6.9       ,  5.        ,
#         3.55      ,  7.85      ,  7.605     ,  3.3       ,  6.9       ,
#         5.99      ,  6.571     ,  6.6       ,  4.86895   ,  7.15      ,
#         8.703     ,  4.8       ,  4.82      ,  4.4       ,  7.65      ,
#         4.75      ,  4.8725    ,  5.52      ,  5.49      ,  6.05      ,
# ...

# %%
#  if we use the normal equation, we get the following weights

normal_equation(X_scaled_with_ones_col, y_scaled)
# Out:
# array([1.84435245, 2.29495219])

# %% [markdown]
# ###### these weights (w0=1.84 and w1=2.29) are much closer in value now, it will be much easier to visualize in a plot
#
# ##### so really important note for below -> we know the correct weights are w0=1.84 and w1=2.29, so when we use gradient descent with our cost function, we need to end up with the same answer... w0=1.84 and w1=2.29

# %% [markdown]
# # Lets plot a cost function

# %% [markdown]
# ### debugging plot function
# I'm going to explicitly perform operations before throwing everything into a function, because if I put everything in a function first, I often have a hard time debugging

# %%
steps = np.linspace(-3, 3, 5)  # this mesh contains 1.84 and 2.29
w0, w1 = np.meshgrid(steps, steps)
w0_ = w0.ravel()
w1_ = w1.ravel()
w = np.column_stack([w0_, w1_])
w
# Out:
# array([[-3. , -3. ],
#        [-1.5, -3. ],
#        [ 0. , -3. ],
#        [ 1.5, -3. ],
#        [ 3. , -3. ],
#        [-3. , -1.5],
#        [-1.5, -1.5],
#        [ 0. , -1.5],
#        [ 1.5, -1.5],
#        [ 3. , -1.5],
#        [-3. ,  0. ],
#        [-1.5,  0. ],
#        [ 0. ,  0. ],
#        [ 1.5,  0. ],
#        [ 3. ,  0. ],
#        [-3. ,  1.5],
#        [-1.5,  1.5],
#        [ 0. ,  1.5],
#        [ 1.5,  1.5],
#        [ 3. ,  1.5],
#        [-3. ,  3. ],
#        [-1.5,  3. ],
#        [ 0. ,  3. ],
#        [ 1.5,  3. ],
#        [ 3. ,  3. ]])

# %%
def calculateCostArray(X, y, i):
    return computeCost(X, y, w[i])

# %%
def computeCost(X, y, w):
    t = X @ w - y
    t_squared = t * t   # vectorized. element wise squaring
    cost = 1/(2*len(X)) * sum(t_squared)
    return cost

# %%
costs = np.zeros(25)
for i in range(25):
    costs[i] = calculateCostArray(X_scaled_with_ones_col, y_scaled, i)
costs
# Out:
# array([103.8953668 ,  84.11030263,  66.57523846,  51.29017429,
#         38.25511012,  68.49023956,  52.57023451,  38.90022947,
#         27.48022442,  18.31021937,  40.65042453,  28.5954786 ,
#         18.79053267,  11.23558675,   5.93064082,  20.37592169,
#         12.18603489,   6.24614808,   2.55626128,   1.11637447,
#          7.66673107,   3.34190338,   1.2670757 ,   1.44224802,
#          3.86742033])

# %%
costs.shape
# Out:
# (25,)

# %%
costs = costs.reshape(5, 5, -1)
costs = costs.squeeze()
costs
# Out:
# array([[103.8953668 ,  84.11030263,  66.57523846,  51.29017429,
#          38.25511012],
#        [ 68.49023956,  52.57023451,  38.90022947,  27.48022442,
#          18.31021937],
#        [ 40.65042453,  28.5954786 ,  18.79053267,  11.23558675,
#           5.93064082],
#        [ 20.37592169,  12.18603489,   6.24614808,   2.55626128,
#           1.11637447],
#        [  7.66673107,   3.34190338,   1.2670757 ,   1.44224802,
#           3.86742033]])

# %%
costs.shape
# Out:
# (5, 5)

# %%
fig2, ax2 = plt.subplots()
ax2.imshow(costs, origin='lower', extent=(w0.min(), w0.max(), w1.min(), w1.max()))
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
# above is working, we can throw everything into a function now and increase the resolution

# %%
def plot(g):
    g2 = g*g
    steps = np.linspace(-4, 6, g)
    w0, w1 = np.meshgrid(steps, steps)
    w0_ = w0.ravel()
    w1_ = w1.ravel()
    w = np.column_stack([w0_, w1_])
    
    def calculateCostArray(X, y, i):
        return computeCost(X, y, w[i])
    
    def computeCost(X, y, w):
        t = X @ w - y
        t_squared = t * t   # vectorized. element wise squaring
        cost = 1/(2*len(X)) * sum(t_squared)
        return cost
    
    costs = np.zeros(g2)
    for i in range(g2):
        costs[i] = calculateCostArray(X_scaled_with_ones_col, y_scaled, i)
    
    costs = costs.reshape(g, g, -1)
    costs = costs.squeeze()
    
    fig3, ax3 = plt.subplots()

    ax3.imshow(costs, origin='lower', extent=(w0.min(), w0.max(), w1.min(), w1.max()))
    ax3.set_title("Cost Function of all the Samples in Figure 1")
    ax3.set_xlabel('$w_0$')
    ax3.set_ylabel('$w_1$')
#     ax3.colorbar()
#     ax3.xlabel('$w_0$')
#     ax3.ylabel('$w_1$')
#     ax3.title('Plot of $cost(\\mathbf{w})$')
#     ax3.gca().set_aspect('equal')  # Force the x and y axes to scale
    

    ax3.contour(w0, w1, costs, colors='white', linestyles=':')


plot(100)
# Out:
# <img src="data:image/png;base64,..." width="432">

# %% [markdown]
# this looks good. Upon visual inspection the cost function, I can see that (w0=1.84, w1=2.29) does seem to lie in the darkest part of the cost function. The cost function will be a bowl like shape. Since there's only one feature, I'm aware that there will be only one global minimum. I know this because when I did my hand calculations with just three samples, I've noticed that, the cost function ends up as a 2nd degree polynomial, and that always has a shape of a bowl. Adding more samples to our cost function will still only produce a second degree polynomial, hence one global minimum.
#
# The darkest region within this cost function represents the lowest point of our cost function. We want to let the algorithm know, that has to pay a cost, for the the pair of weights (w0, w1) it picks. Every pair of weights has an associated cost. An algorithm will pick the lowest point on the cost function as this corresponds to the lowest cost.

# %% [markdown]
# ##### we can also visualize the cost function in a 3D space, instead of a contour plot to further get comfortable with the cost function.

# %%
# %matplotlib notebook

from mpl_toolkits.mplot3d import axes3d

bounds = 5

x1 = np.linspace(-bounds, bounds, 5)
x2 = np.linspace(-bounds, bounds, 5)

X1, X2 = np.meshgrid(x1, x2)

# Z = f(X1, X2)

fig1, ax1 = plt.subplots()
# fig = plt.figure()
ax1 = plt.axes(projection='3d')

ax1.contour3D(X1, X2, costs, 30)
# ax.plot_wireframe(X1, X2, Z, rstride=5, cstride=5)


ax1.set_xlabel(r'$\theta_0$')
ax1.set_ylabel(r'$\theta_1$')
ax1.set_zlabel('Cost')
# Out:
# <img src="data:image/png;base64,..." width="432">
# Text(0.5, 0, 'Cost')

# %% [markdown]
# Where we are in the project => We have a cost function representation.
#
# Now we need to apply gradient descent to our cost function. A gradient descent algorithm with a good learning rate, and sufficient iterations, we need to get w0=1.84 and w1=2.29

# %% [markdown]
# ### gradient descent

# %%
# recall, from the normal equation, we're know 
# we should get w0=1.84 and w1=2.29

normal_equation(X_scaled_with_ones_col, y_scaled)
# Out:
# array([1.84435245, 2.29495219])

# %%
def gradient_descent(X, y, learn_rate=0.00004, num_steps= 10000):
    w = np.array([0, 0]) # so instead of guessing x, we're guessing w
    for i in range(num_steps):
        grad = (X.T @ X) @ w - X.T @ y  # so.. this is a very useful equation
        w = w - learn_rate*grad
    return w

gradient_descent(X_scaled_with_ones_col, y_scaled)
# Out:
# array([1.84270283, 2.29581986])

# %%
# 0.0004 learning rate is quite low and 10000 iterations is quite high

# %%
w_from_gradient_descent = gradient_descent(X_scaled_with_ones_col, y_scaled)
w_from_gradient_descent
# Out:
# array([1.84270283, 2.29581986])

# %% [markdown]
# we indeed get w0 is 1.84 and w1 is 2.29. the same answer as our normal equation

# %%
plot(100)
plt.plot(*w_from_gradient_descent, 'xr')
# Out:
# <img src="data:image/png;base64,..." width="432">
